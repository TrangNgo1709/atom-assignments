# %% [markdown]
# # HOME ASSIGNMENT #4: DATABASE DESIGN & SQL
#
# **Mục đích của bài Assignment**
# > *   Hiểu các bước design Database cho Case study cụ thể: DataCracy
# *   Bài tập SQL (Dựa trên Cheatsheet)
# *   `[Optional]` Bài tập Python Pandas (Dựa trên Cheatsheet)
#
# **Các kiến thức áp dụng**
# * Slack API, JSON to DataFrame
# * Phân tích Data (Assignment#1, Lab#1)
# * Database (DB) Design
# * SQL
# * Python Pandas
#
# **Lời Khuyên**
# * Đây là bài tập dài, nhưng thiên về hiểu case studies và thiết kế => Nên bạn **hãy bắt đầu sớm**
# * **Chắc chắn là bạn đọc thực kỹ các bước hướng dẫn và tài liệu, tận dụng Slack để trao đổi**
# * **Đừng sa đà vào Code của STEP 0** (bước này tương tự Assignmetn 3 về Slack API, nhưng biến đổi thêm cho phù hợp)
# * **Đừng sa đà vào các tiểu tiết** => Rất quan trọng là bạn cố gắng đi đến hết `TODO#6` để hiểu bức tranh toàn cảnh và kết nối được kiến thức. Sau khi đi hết qua, các bạn có thể trở lại và nhìn cận vào các tiểu tiết
# * Làm nhiều nhất có thể (Đừng quá lo lắng nếu bạn không thể hoàn thành hết)

# %% [markdown]
# # CONCEPT: DB Design & SQL
# ## **Database (DB) - Cơ sở dữ liệu**
# > Là cấu trúc các nhóm data, lưu trữ trên bộ nhớ hoặc trên cloud, cho phép truy nhập để trích xuất dữ liệu bằng nhiều cách thức khác nhau
#
# * Cấu trúc một DB phải giúp cho việc lưu trữ an toàn, tiết kiệm, linh động và bền vững. Đồng thời, việc trích xuất dữ liệu dễ dàng, nhanh chóng, và hiệu quả.
# * Dạng DB đề cập trong Atom chủ yếu là **Relational Database** => Đây là dạng cấu trúc:
#   * Dữ liệu được tổ chức và lưu trữ dưới dáng bảng (tables)
#   * Đặc trưng có các keys (Primary Keys - PK, Foreign Keys - FK) để biểu diễn/quy định mối quan hệ giữa các bảng. Chính nhờ các keys này, ta có thể kết nối các bảng khác nhau.
#   * Việc tách dữ liệu thành các bảng giúp việc tổ chức dữ liệu được linh động, lưu trữ hiệu quả hơn. Nhưng vẫn đảm bảo việc dễ dàng kết nối các bảng bằng keys
# * Ngoài ra, còn có dạng **Non-relational Database** các bạn có thể tìm hiểu thêm ([Databases 101](https://towardsdatascience.com/databases-101-introduction-to-databases-for-data-scientists-ee18c9f0785d))
#
# ## **DB Design**
# > Là quá trình thiết kế và tổ chức dữ liệu theo mô hình Database. Thiết kế quy định những dữ liệu gì được lưu trữ, tổ chức các bảng được lưu trữ như thế nào, và các bảng data liên quan đến nhau ra sao.
#
# * **Thiết kế DB cần thoả mãn**:
#   1. Hạn chế trùng lặp trong lưu trữ thông tin
#   2. Keys chỉ mối quan hệ của các bảng (PK, FK) hợp lý
#   3. Kiểm tra tính đúng đắn (liên hệ keys, chất lượng data)
#   4. Hỗ trợ hiệu quả nhất cho quá trình xử lý, phân tích và báo cáo
#
# ## **SQL**
# * Là ngôn ngữ dùng để trích xuất, xử lý và phân tích data trên Rational Database

# %% [markdown]
# # CASE STUDY: DATACracy
# * **Context**: Không có doanh nghiệp hay tổ chức nào là quá nhỏ để dùng data, và bất kỳ tổ chức nào có vận hành (operation) thì nhất định sẽ sản sinh ra data, và có thể dùng data để theo dõi và cải thiện vận hành đó (Đọc: [DataCracy - Data Strategy](https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics))
# * **Hoạt động/Vận hành**:
#   * Datacracy đang vận hành lớp học mở ATOM (với 40 learners, 6 mentors, và Ban Tổ Chức)
#   * Lớp học diễn ra mỗi tuần, với bài tập được gửi vào sáng Chủ Nhật và hoàn thành trước buổi học sáng T7
#   * Các bạn Learners upload link (github) vào các Slack channels theo tuần (ví dụ: `#atom-assignment-1`)
#   * Các hoạt động trao đổi, hướng dẫn giữa learners, mentors và BTC chủ yếu diễn ra trong tuần qua Slack
#
#
# > Bản thân Datacracy cũng có vận hành và các hoạt động. Vậy hãy dùng chính mình làm case study cho việc, ta có thể tạo ra data solution siêu nhỏ, siêu rẻ cho một tổ chức quy mô siêu nhỏ như DataCracy không?

# %% [markdown]
# Trong **Assignment** này, chúng ta sẽ đi qua **6 bước chính** của quá trình design DB (cho case study cụ thể của DataCracy)
# ![Screen Shot 2021-05-23 at 01.45.40.png](data:image/png;base64,...)

# %%
# !pip install duckdb
# Out:
# Collecting duckdb
#   Downloading https://files.pythonhosted.org/packages/86/57/d6c01b90435e5aa08421831556cf2abed72be7f79eeef029c2e239bda390/duckdb-0.2.6-cp37-cp37m-manylinux2010_x86_64.whl (8.5MB)
#      |████████████████████████████████| 8.5MB 8.7MB/s
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.7/dist-packages (from duckdb) (1.19.5)
# Installing collected packages: duckdb
# Successfully installed duckdb-0.2.6

# %%
import requests # -> Để call API
import json # -> Xử lý file JSON
import pandas as pd # -> Thư viện xử lý dữ liệu dạng bảng
import re # -> Thư viện xử lý text: regular expressions
from datetime import datetime as dt # -> Thư viện xử lý dữ liệu thời gian
import duckdb # -> Thư viện "giả lập" xử lý dữ liệu bằng SQL

# %% [markdown]
# ## STEP 0: XEM LẠI DATA ĐÃ CÓ (SLACK API)
#
# Ở bước đầu tiên, ta xem lại tất cả các data của DATACracy Atom mà ra đã biết:
# * **Data từ Slack API**:
#   * Danh sách thành viên
#   * Danh sách các channels
#   * Lịch sử tin nhắn trên các channels
# * **Data do dự án tự collect - File CSV (trích xuất từ Google Spreadsheet)**:
#   * Danh sách thành viên được phân theo vị trí (mentors, learners, BTC)
#
#
# ===> Các dữ liệu này lần lượt được lấy bằng code bên dưới.

# %%
## Load Token file 
## WARNING!! --- Put it in gitignore and DO NOT print out to notebook
with open('env_variable.json', 'r') as j:
    json_data = json.load(j)

# %% [markdown]
# ### 0.1. Pull List of Members

# %%
# 1. LIST OF SLACK MEMBERS 

## Pull list of member as JSON
## Gọi API từ Endpoints (Input - Token được đưa vào Headers)
## Challenge: Thử gọi API này bằng Postman
endpoint = "https://slack.com/api/users.list"
headers = {"Authorization": "Bearer {}".format(json_data['SLACK_BEARER_TOKEN'])}
response_json = requests.post(endpoint, headers=headers).json() 
user_dat = response_json['members']

## Convert to CSV
user_dict = {'user_id':[],'name':[],'display_name':[],'real_name':[],'title':[],'is_bot':[]}
for i in range(len(user_dat)):
  user_dict['user_id'].append(user_dat[i]['id'])
  user_dict['name'].append(user_dat[i]['name'])
  user_dict['display_name'].append(user_dat[i]['profile']['display_name'])
  user_dict['real_name'].append(user_dat[i]['profile']['real_name_normalized'])
  user_dict['title'].append(user_dat[i]['profile']['title'])
  user_dict['is_bot'].append(user_dat[i]['is_bot'])

user_df = pd.DataFrame(user_dict) 
#user_df = user_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
user_df.head()
# Out:
#        user_id               name  ...               title is_bot
# 0    USLACKBOT           slackbot  ...                      False
# 1  U01AT4T75JB     loclexuan26392  ...                      False
# 2  U01AVDY7JET           locle.ds  ...                      False
# 3  U01BE2PR6LU     maianhdang.ftu  ...  Technical Contents  False
# 4  U01C48T7S1J  huyenhoang.design  ...                      False
#
# [5 rows x 6 columns]

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       75 non-null     object
#  1   name          75 non-null     object
#  2   display_name  75 non-null     object
#  3   real_name     75 non-null     object
#  4   title         75 non-null     object
#  5   is_bot        75 non-null     bool
# dtypes: bool(1), object(5)
# memory usage: 3.1+ KB

# %% [markdown]
# ### 0.2. List of Channels

# %%
# 2. LIST OF SLACK CHANNELS

endpoint2 = "https://slack.com/api/conversations.list"
data = {'types': 'public_channel,private_channel'} # -> CHECK: API Docs https://api.slack.com/methods/conversations.list/test
response_json = requests.post(endpoint2, headers=headers, data=data).json() 
channel_dat = response_json['channels']

channel_dict = {'channel_id':[], 'channel_name':[], 'is_channel':[],'creator':[],'created_at':[],'topics':[],'purpose':[],'num_members':[]}
for i in range(len(channel_dat)):
  channel_dict['channel_id'].append(channel_dat[i]['id'])
  channel_dict['channel_name'].append(channel_dat[i]['name'])
  channel_dict['is_channel'].append(channel_dat[i]['is_channel'])
  channel_dict['creator'].append(channel_dat[i]['creator'])
  channel_dict['created_at'].append(dt.fromtimestamp(float(channel_dat[i]['created'])))
  channel_dict['topics'].append(channel_dat[i]['topic']['value'])
  channel_dict['purpose'].append(channel_dat[i]['purpose']['value'])
  channel_dict['num_members'].append(channel_dat[i]['num_members'])

channel_df = pd.DataFrame(channel_dict) 
#channel_df = channel_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
channel_df.head()
# Out:
#     channel_id  ... num_members
# 0  C01B4PVGLVB  ...          65
# 1  C01BYH7JHB5  ...          12
# 2  C01CAMNCJJV  ...           9
# 3  C01U6P7LZ8F  ...          44
# 4  C01UL6K1C7L  ...          43
#
# [5 rows x 8 columns]

# %%
channel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_id    21 non-null     object
#  1   channel_name  21 non-null     object
#  2   is_channel    21 non-null     bool
#  3   creator       21 non-null     object
#  4   created_at    21 non-null     datetime64[ns]
#  5   topics        21 non-null     object
#  6   purpose       21 non-null     object
#  7   num_members   21 non-null     int64
# dtypes: bool(1), datetime64[ns](1), int64(1), object(5)
# memory usage: 1.3+ KB

# %% [markdown]
# ### 0.3. Message Data

# %%
endpoint3 = "https://slack.com/api/conversations.history"

# %%
msg_dict = {'channel_id':[],'msg_id':[], 'msg_ts':[], 'user_id':[], 'latest_reply':[],'reply_user_count':[],'reply_users':[],'github_link':[]}
for channel_id, channel_name in zip(channel_df['channel_id'], channel_df['channel_name']):
  print('Channel ID: {} - Channel Name: {}'.format(channel_id, channel_name))
  #try:
  data = {"channel": channel_id} 
  response_json = requests.post(endpoint3, data=data, headers=headers).json()
  print(str(response_json))
  if response_json['ok']:
    msg_ls = response_json['messages']
    for i in range(len(msg_ls)):
      if 'client_msg_id' in msg_ls[i].keys():
        msg_dict['channel_id'].append(channel_id)
        msg_dict['msg_id'].append(msg_ls[i]['client_msg_id'])
        msg_dict['msg_ts'].append(dt.fromtimestamp(float(msg_ls[i]['ts'])))
        msg_dict['latest_reply'].append(dt.fromtimestamp(float(msg_ls[i]['latest_reply'] if 'latest_reply' in msg_ls[i].keys() else 0))) ## -> No reply: 1970-01-01
        msg_dict['user_id'].append(msg_ls[i]['user'])
        msg_dict['reply_user_count'].append(msg_ls[i]['reply_users_count'] if 'reply_users_count' in msg_ls[i].keys() else 0)
        msg_dict['reply_users'].append(msg_ls[i]['reply_users'] if 'reply_users' in msg_ls[i].keys() else 0) 
        ## -> Censor message contains tokens
        text = msg_ls[i]['text']
        github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text)
        msg_dict['github_link'].append(github_link[0] if len(github_link) > 0 else "")
  #except:
   # print('====> '+ str(response_json))
# Out:
# Channel ID: C01B4PVGLVB - Channel Name: general
# {'ok': True, 'messages': [{'client_msg_id': 'da7ab6eb-0b3c-4bd6-a12a-589a12c56604', 'type': 'message', 'text': '<!channel> ASSIGNMENT 5 RELEASE\n---\n<#C023UJGMDND|atom-assignment5>\nTuần này sẽ giới thiệu cho mọi người 1 platform mới Kaggle\nBài tập hy vọng là nhẹ nhàng hơn, giúp các bạn xâu chuỗi ôn lại kiến thức nha.\nCó thắc mắc gì tích cực hỏi trên các channel nha mọi ng ơiii\n&gt; RULES: Format submit bài\nNhư chúng ta có học trong bài Database Design, về các rules để năng cao chất lượng data. Học đi đôi với hành, mọi người nộp bài để message theo cú pháp sau nha\n• Name: &lt;slack-user_ID của bạn&gt;\n• Status: DONE\n• Link: &lt;github_link&gt;\n<https://datacracy.slack.com/archives/C023UJGMDND/p1622339742001400>', 'user': 'U01BE2PR6LU', 'ts': '1622340097.001200', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01BE2PR6LU', 'ts': '1622340206.000000'}, 'attachments': [{'from_url': 'https://datacracy.slack.com/archives/C023UJGMDND/p1622339742001400', 'fallback': '[May 29th, 2021 6:55 PM] maianhdang.ftu: *HOME ASSIGNMENT #5: DATABASE DESIGN &amp; SQL*\n----\nMọi người ơi, Assignment#5 đã lên sóng.\n• Đây là bài tập nhẹ nhàng hơn các tuần trước\n• Các bạn dành thời gian ôn lại và xâu chuỗi kiến thức nhé: Slack API, GSheet, SQL và Python\n---\n1. <https://github.com/anhdanggit/atom-assignments#readme|README về Update forked repo>\xa0(cập nhật bài tập mới từ repo gốc)\n2. :tada:\xa0:tada:\xa0\xa0<https://github.com/anhdanggit/atom-assignments/blob/main/assignment_5/home_assignment_5.ipynb|Assignment 5>\n---\n&gt; RULES: Format submit bài\nNhư chúng ta có học trong bài Database Design, về các rules để năng cao chất lượng data. Học đi đôi với hành, mọi người nộp bài để message theo cú pháp sau nha\n• Name: &lt;slack-user_ID của bạn&gt;\n• Status: DONE\n• Link: github\n---\n:warning:\xa0Lần nãy vẫn dùng Token, nên mọi người cẩn thận củi lửa, đừng print key, và nhớ gitignore nhoé\n:green_heart:\xa0\xa0Bất kỳ câu hỏi thắc mắc nào các bạn hãy raise trong channel <#C0245PZUFSL|atom-week5> nhé\n:green_heart:\xa0Các channels riêng cho nhóm đã được tạo để tiện trao đổi: #discuss-group\n:red_circle:\xa0Bài tập Đợt 1 hoàn thành và post link trong channel này\xa0trước buổi học tiếp theo\n:red_circle:\xa0*Bài tập*\xa0“Last Chance”: Sau buổi học, học viên có thể hoàn chỉnh thêm assignment theo nội dung review trong lớp học, và submit lại\xa0`trước *12h đêm Chủ nhật`\xa0(sau buổi học)*', 'ts': '1622339742.001400', 'author_id': 'U01BE2PR6LU', 'author_subname': 'Đặng Huỳnh Mai Anh', 'channel_id': 'C023UJGMDND', 'channel_name': 'atom-assignment5', 'is_msg_unfurl': True, 'text': '*HOME ASSIGNMENT #5: DATABASE DESIGN &amp; SQL*\n----\nMọi người ơi, Assignment#5 đã lên sóng.\n• Đây là bài tập nhẹ nhàng hơn các tuần trước\n• Các bạn dành thời gian ôn lại và xâu chuỗi kiến thức nhé: Slack API, GSheet, SQL và Python\n---\n1. <https://github.com/anhdanggit/atom-assignments#readme|README về Update forked repo>\xa0(cập nhật bài tập mới từ repo gốc)\n2. :tada:\xa0:tada:\xa0\xa0<https://github.com/anhdanggit/atom-assignments/blob/main/assignment_5/home_assignment_5.ipynb|Assignment 5>\n---\n&gt; RULES: Format submit bài\nNhư chúng ta có học trong bài Database Design, về các rules để năng cao chất lượng data. Học đi đôi với hành, mọi người nộp bài để message theo cú pháp sau nha\n• Name: &lt;slack-user_ID của bạn&gt;\n• Status: DONE\n• Link: github\n---\n:warning:\xa0Lần nãy vẫn dùng Token, nên mọi người cẩn thận củi lửa, đừng print key, và nhớ gitignore nhoé\n:green_heart:\xa0\xa0Bất kỳ câu hỏi thắc mắc nào các bạn hãy raise trong channel <#C0245PZUFSL|atom-week5> nhé\n:green_heart:\xa0Các channels riêng cho nhóm đã được tạo để tiện trao đổi: #discuss-group\n:red_circle:\xa0Bài tập Đợt 1 hoàn thành và post link trong channel này\xa0trước buổi học tiếp theo\n:red_circle:\xa0*Bài tập*\xa0“Last Chance”: Sau buổi học, học viên có thể hoàn chỉnh thêm assignment theo nội dung review trong lớp học, và submit lại\xa0`trước *12h đêm Chủ nhật`\xa0(sau buổi học)*', 'aut ...
# Channel ID: C01BYH7JHB5 - Channel Name: contents
# {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C01CAMNCJJV - Channel Name: branding-design
# {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C01U6P7LZ8F - Channel Name: atom-assignment1
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216202.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856793.004500', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756508.004100', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621649053.002000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621573064.000900', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621529006.000600', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621475882.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621356309.001300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621271471.002600', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_topic', 'ts': '1621074484.005600', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 - Python Basics &amp; Spreadsheet Analysis', 'topic': 'Assigment#1 - Python Basics &amp; Spreadsheet Analysis'}, {'type': 'message', 'subtype': 'channel_topic', 'ts': '1621074460.005500', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 - Submissions + Reviews', 'topic': 'Assigment#1 - Submissions + Reviews'}, {'type': 'message', 'subtype': 'channel_purpose', 'ts': '1621074440.005400', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> set the channel description: Where learners submit assignments and give review for others', 'purpose': 'Where learners submit assignments and give review for others'}, {'type': 'message', 'subtype': 'channel_topic', 'ts': '1621074401.005300', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 Submissions + Reviews', 'topic': 'Assigment#1 Submissions + Reviews'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621072722.005000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '005AD620-BD06-4123-BC42-6118DAA73BA4', 'type': 'message', 'text': 'Em xin chào mọi người ạ. Híc, em bị stuck ở phần bài tập 2 nên ngoi lên nhờ mọi người chỉ giáo với ạ :smiling_face_with_tear: \n\nCụ thể em làm tới đoạn App password và API xong, nhưng tới đoạn code từ !1s trong phần Environment Variables thì em không hiểu là mình viết đoạn này vào Google Colab hay vào đâu ạ? Em cũng thử trên Jupiter Notebook nhưng không được.\n\nFile bài đọc Medium ở #Lab2 em hiện chưa tìm cách nào vào được nên bị miss mất nội dung Set-up working environment ạ.\n\nKhông làm được bài nên ngứa ngáy trong mình :joy:, mong mọi người giúp đỡ ạ. Em xin cảm ơn :pray::skin-tone-2:', 'user': 'U01UTGRMGEQ', 'ts': '1620914988.011000', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'TrZ', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Em xin chào mọi người ạ. Híc, em bị stuck ở phần bài tập 2 nên ngoi lên nhờ mọi người chỉ giáo với ạ '}, {'type': 'emoji', 'name': 'smiling_face_with_tear'}, {'type': 'text', 'text': ' \n\nCụ thể em làm tới đoạn App password và API xong, nhưng tới đoạn code từ !1s trong phần Environment Variables thì em không hiểu là mình viết  ...
# Channel ID: C01UL6K1C7L - Channel Name: atom-week1
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216228.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856828.000900', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756540.000600', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621700336.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '95a97922-b168-4fa1-ad8f-9330ad791f38', 'type': 'message', 'text': 'Chúc cô <@U01BE2PR6LU> nhanh khỏe ạ. :muscle::muscle:', 'user': 'U01UMJ36QD9', 'ts': '1619219500.005700', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': '8AGT', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chúc cô '}, {'type': 'user', 'user_id': 'U01BE2PR6LU'}, {'type': 'text', 'text': ' nhanh khỏe ạ. '}, {'type': 'emoji', 'name': 'muscle'}, {'type': 'emoji', 'name': 'muscle'}]}]}], 'reactions': [{'name': 'raised_hands', 'users': ['U01BE2PR6LU'], 'count': 1}]}, {'client_msg_id': '74637683-38A8-424D-8288-81B29C7C5B16', 'type': 'message', 'text': 'Chúc teacher <@U01BE2PR6LU> mau khoẻ nhé! Hy vọng sau lễ sẽ được nghe teacher giảng bài :)', 'user': 'U01VB632FPS', 'ts': '1619215043.003600', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': '4sRtN', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chúc teacher '}, {'type': 'user', 'user_id': 'U01BE2PR6LU'}, {'type': 'text', 'text': ' mau khoẻ nhé! Hy vọng sau lễ sẽ được nghe teacher giảng bài :)'}]}]}], 'thread_ts': '1619215043.003600', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1619217254.004100', 'reply_users': ['U01UMBZHU2W'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'raised_hands', 'users': ['U01BE2PR6LU'], 'count': 1}]}, {'client_msg_id': '9a20a3fd-1a07-49f9-8114-734baffb1862', 'type': 'message', 'text': 'Nộp bài: <https://github.com/nvlinh209/datacracy-atom-Nguyen-Van-Linh/blob/main/README.md> <https://drive.google.com/file/d/1vRmt6kXA1N7xnvWWMMbOThmW-6UHED_Q/view?usp=sharing> <https://colab.research.google.com/drive/1rdYsA5xrBBDfQeBorM7sDePOP6tagCfs?usp=sharing>', 'user': 'U01UMBXJLHG', 'ts': '1619182343.000700', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1rdYsA5xrBBDfQeBorM7sDePOP6tagCfs?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1rdYsA5xrBBDfQeBorM7sDePOP6tagCfs?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1rdYsA5xrBBDfQeBorM7sDePOP6tagCfs?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'pFDXP', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Nộp bài: '}, {'type': 'link', 'url': 'https://github.com/nvlinh209/datacracy-atom-Nguyen-Van-Linh/blob/main/README.md'}, {'type': 'text', 'text': ' '}, {'type': 'link', 'url': 'https://drive.google.com/file/d/1vRmt6kXA1N7xnvWWMMbOThmW-6UHED_Q/view?usp=sharing'}, {'type': 'text', 'text': ' '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1rdYsA5xrBBDfQeBorM7sDePOP6tagCfs?usp=sharing'}]}]}], 'thread_ts': '1619182343.000700', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1619182496.001100', 'reply_users': ['U01V00LQ7EV'], 'is_locked': False, 'subscribed': False}, ...
# Channel ID: C01ULCHGN75 - Channel Name: atom-general
# {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C020VMT58JK - Channel Name: topics-data-analytics
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216316.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621868466.000400', 'user': 'U01UJ9MUADT', 'text': '<@U01UJ9MUADT> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856882.000200', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756610.002700', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621749702.002500', 'user': 'U01UMJ5AQ0K', 'text': '<@U01UMJ5AQ0K> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621659170.002300', 'user': 'U01UJ9PRT5K', 'text': '<@U01UJ9PRT5K> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621658043.002100', 'user': 'U01UMJ36QD9', 'text': '<@U01UMJ36QD9> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621658021.001900', 'user': 'U01UMJ451V1', 'text': '<@U01UMJ451V1> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621658019.001700', 'user': 'U01UMBZHU2W', 'text': '<@U01UMBZHU2W> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657972.001500', 'user': 'U01UMBW8G8J', 'text': '<@U01UMBW8G8J> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657966.001300', 'user': 'U01V00JK9LH', 'text': '<@U01V00JK9LH> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657953.001100', 'user': 'U01UTGRMGEQ', 'text': '<@U01UTGRMGEQ> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657902.000800', 'user': 'U020P6WPAQJ', 'text': '<@U020P6WPAQJ> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657897.000600', 'user': 'U01VB632FPS', 'text': '<@U01VB632FPS> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657888.000400', 'user': 'U01V082PLN5', 'text': '<@U01V082PLN5> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621657886.000200', 'user': 'U01V00P4S2V', 'text': '<@U01V00P4S2V> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621074537.000400', 'user': 'U01V00KHHHP', 'text': '<@U01V00KHHHP> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621034032.000200', 'user': 'U01UMBX2X18', 'text': '<@U01UMBX2X18> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621015166.000200', 'user': 'U01V00LQ7EV', 'text': '<@U01V00LQ7EV> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620638103.000200', 'user': 'U01UTGVPE7N', 'text': '<@U01UTGVPE7N> has joined the channel'}, {'type': 'message', 'subtype': 'channel_name', 'ts': '1620453962.000300', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> has renamed the channel from "discuss-data-analytics" to "topics-data-analytics"', 'old_name': 'discuss-data-analytics', 'name': 'topics-data-analytics'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620453940.000200', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> has joined the channel'}], 'has_more': False, 'pin_count': 0, 'channel_actions_ts': None, 'channel_actions_count': 0}
# Channel ID: C0213MNH9L6 - Channel Name: topics-python
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216334.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856894.015600', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': 'f153bea2-aa46-4061-b212-5163d5a11619', 'type': 'message', 'text': 'Mọi người ơi, mình đang gặp 1 lỗi hết sức phức tạp "Unable to open \'home_assignment_3 copy.ipynb\': Unexpected token &lt; in JSON at position 4098." Mình đang làm và chạy lệnh xong hết, đến đoạn commit và push lên github thì bị trục trặc mãi không push được. Đến khi push xong thì cả file trên github và file trong máy mình đều không mở được nữa. Có ai giúp xem mình đang bị lỗi gì không ạ\n<https://github.com/Tenderriver/atom-assignments/tree/main/assignment_3>', 'user': 'U01U6JQB695', 'ts': '1621791325.004500', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01U6JQB695', 'ts': '1621791771.000000'}, 'blocks': [{'type': 'rich_text', 'block_id': '1DcAw', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mọi người ơi, mình đang gặp 1 lỗi hết sức phức tạp "Unable to open \'home_assignment_3 copy.ipynb\': Unexpected token < in JSON at position 4098." Mình đang làm và chạy lệnh xong hết, đến đoạn commit và push lên github thì bị trục trặc mãi không push được. Đến khi push xong thì cả file trên github và file trong máy mình đều không mở được nữa. Có ai giúp xem mình đang bị lỗi gì không ạ\n'}, {'type': 'link', 'url': 'https://github.com/Tenderriver/atom-assignments/tree/main/assignment_3'}]}]}], 'thread_ts': '1621791325.004500', 'reply_count': 20, 'reply_users_count': 2, 'latest_reply': '1621830027.015000', 'reply_users': ['U01VBGPP1EU', 'U01U6JQB695'], 'is_locked': False, 'subscribed': False}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756626.004000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621700355.003700', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621659556.001500', 'user': 'U01UJ9P1S3X', 'text': '<@U01UJ9P1S3X> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '3c51c3ee-9eca-4ab0-b3aa-0649eb973c97', 'type': 'message', 'text': '<!channel> TỰ TẠO SLACK API TOKEN\n----\nCó nhiều bạn Learners tự tạo API Token luôn, có thể chia sẻ kinh nghiệm của đây nha\nTag đại diện: <@U01UJ9P1S3X> <@U01UMJ5AQ0K>', 'user': 'U01BE2PR6LU', 'ts': '1621659553.001300', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'S53', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'channel'}, {'type': 'text', 'text': ' TỰ TẠO SLACK API TOKEN\n----\nCó nhiều bạn Learners tự tạo API Token luôn, có thể chia sẻ kinh nghiệm của đây nha\nTag đại diện: '}, {'type': 'user', 'user_id': 'U01UJ9P1S3X'}, {'type': 'text', 'text': ' '}, {'type': 'user', 'user_id': 'U01UMJ5AQ0K'}]}]}], 'thread_ts': '1621659553.001300', 'reply_count': 3, 'reply_users_count': 3, 'latest_reply': '1621687931.003200', 'reply_users': ['U01UMJ5AQ0K', 'U01UJ9P1S3X', 'U01BE2PR6LU'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'innocent', 'users': ['U01UMJ5AQ0K'], 'count': 1}]}, {'type': 'message', 'subtype': 'thread_broadcast', 'text': 'em vẫn chưa solve đc task weather có ai giúp em xem qua đc hông ạ TT', 'user': 'U01UMBZHU2W', 'ts': '1621603103.021700', 'thread_ts': '1621537564.010600', 'root': {'type': 'message', 'text': 'hic mn ơi bữa giờ em bị kẹt ở task gửi mail weather London nên chưa thể làm tiếp được. Em chưa biết làm sao để nội dung email có thể gửi được weather London.\nEm có thử đổi nhiều cách nhưng nó vẫn gửi email với nội dung y chang như ở Todo2\ncó ai có thể gợi ý cho em ở step n ...
# Channel ID: C0213N56M2A - Channel Name: topics-materials
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216327.002000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '79061d75-9d76-45b0-b19b-c431c16b56c1', 'type': 'message', 'text': 'mn ơi, em muốn tìm một khóa học basic PowerBI. Có ai có khóa nào hay có thể giới thiệu cho em hông?\nEm cám ơn mn nhiềuuu', 'user': 'U01UMBZHU2W', 'ts': '1622196254.001100', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'JU0x', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'mn ơi, em muốn tìm một khóa học basic PowerBI. Có ai có khóa nào hay có thể giới thiệu cho em hông?\nEm cám ơn mn nhiềuuu'}]}]}], 'thread_ts': '1622196254.001100', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1622197368.001600', 'reply_users': ['U01UJ9PRT5K', 'U01UMBZHU2W'], 'is_locked': False, 'subscribed': False}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856889.000800', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756620.000500', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621659218.000200', 'user': 'U01UJ9PRT5K', 'text': '<@U01UJ9PRT5K> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621476890.000200', 'user': 'U020P877V88', 'text': '<@U020P877V88> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621134979.000200', 'user': 'U01VB632FPS', 'text': '<@U01VB632FPS> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621074531.000400', 'user': 'U01V00KHHHP', 'text': '<@U01V00KHHHP> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621034032.000200', 'user': 'U01UMBX2X18', 'text': '<@U01UMBX2X18> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621015165.000400', 'user': 'U01V00LQ7EV', 'text': '<@U01V00LQ7EV> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621011530.000200', 'user': 'U01UJ9NKX8D', 'text': '<@U01UJ9NKX8D> has joined the channel'}, {'client_msg_id': '84dba98f-8843-4684-a68d-6be491f9e915', 'type': 'message', 'text': 'Chia sẻ với các bạn 1 website có lược dịch chương 1 của cuốn "*Automate The Boring Stuff With Python"* nhé ^^\n<https://pycon.vn/t/atbs2nd-luoc-dich-cuon-sach-automate-the-boring-stuff-with-python-cua-al-sweigart/113|pycon.vn/t/atbs2nd-luoc-dich-cuon-sach-automate-the-boring-stuff-with-python-cua-al-sweigart/113>', 'user': 'U01U6JQB695', 'ts': '1620827702.002600', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'yAQ', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chia sẻ với các bạn 1 website có lược dịch chương 1 của cuốn "'}, {'type': 'text', 'text': 'Automate The Boring Stuff With Python" ', 'style': {'bold': True}}, {'type': 'text', 'text': 'nhé ^^\n'}, {'type': 'link', 'url': 'https://pycon.vn/t/atbs2nd-luoc-dich-cuon-sach-automate-the-boring-stuff-with-python-cua-al-sweigart/113', 'text': 'pycon.vn/t/atbs2nd-luoc-dich-cuon-sach-automate-the-boring-stuff-with-python-cua-al-sweigart/113'}]}]}], 'reactions': [{'name': 'heart', 'users': ['U01V082PLN5', 'U01UMC08KL2'], 'count': 2}]}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620827415.000200', 'user': 'U01U6JQB695', 'text': '<@U01U6JQB695> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620775522.000200', 'user': 'U01UMBW8G8J', 'text': '<@U01UMBW8G8J> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620634147.000400', 'user': 'U01UMJ451V1', 'text': '<@U01UMJ451V1> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620632164.000200', 'user': 'U01UTGS5ZN ...
# Channel ID: C021FSDN7LJ - Channel Name: atom-assignment2
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216208.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856809.026000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756516.024000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': 'dad18eb3-8434-4188-b43e-694c3b5bf215', 'type': 'message', 'text': 'Dạ em chưa được review ạ. Bài tập tuần 2 em đã revised ở\xa0<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%202_Link%20of%20assignment%20for%20peer%20review|link này>.\nEm cũng xin thành thật khai báo là bữa giờ em chưa kịp đi review bài 2 của ai cả, em sẽ review ngay trong hôm nay ạ. :joy:', 'user': 'U01UTGRMGEQ', 'ts': '1621661974.015500', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01UTGRMGEQ', 'ts': '1622039140.000000'}, 'attachments': [{'text': '```\nGoogle Colab: <https://colab.research.google.com/drive/1tJnkgpmECc9iNikXYiEltTotMVMCotlO?usp=sharing>\n\n```', 'title': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%202_Link%20of%20assignment%20for%20peer%20review | WEEK 2_Link of assignment for peer review>', 'footer': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh|nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh>', 'id': 1, 'footer_icon': 'https://slack.github.com/static/img/favicon-neutral.png', 'color': '24292f', 'mrkdwn_in': ['text'], 'fallback': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%202_Link%20of%20assignment%20for%20peer%20review | WEEK 2_Link of assignment for peer review>', 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%202_Link%20of%20assignment%20for%20peer%20review', 'is_app_unfurl': True}], 'blocks': [{'type': 'rich_text', 'block_id': '2gy', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Dạ em chưa được review ạ. Bài tập tuần 2 em đã revised ở\xa0'}, {'type': 'link', 'url': 'https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%202_Link%20of%20assignment%20for%20peer%20review', 'text': 'link này'}, {'type': 'text', 'text': '.\nEm cũng xin thành thật khai báo là bữa giờ em chưa kịp đi review bài 2 của ai cả, em sẽ review ngay trong hôm nay ạ. '}, {'type': 'emoji', 'name': 'joy'}]}]}], 'thread_ts': '1621661974.015500', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1621693138.019900', 'reply_users': ['U01UTGRMGEQ'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'scream', 'users': ['U01BE2PR6LU'], 'count': 1}]}, {'client_msg_id': 'fc264fbb-a5f6-4f27-a692-4631721e4912', 'type': 'message', 'text': '<!channel> Mọi người review bài tập cho nhau nhé. Ai chưa dc review thì hú lên ở đây nha :boxing_glove: :love_letter:', 'user': 'U01BE2PR6LU', 'ts': '1621661391.013900', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': '+5Nby', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'broadcast', 'range': 'channel'}, {'type': 'text', 'text': ' Mọi người review bài tập cho nhau nhé. Ai chưa dc review thì hú lên ở đây nha '}, {'type': 'emoji', 'name': 'boxing_glove'}, {'type': 'text', 'text': ' '}, {'type': 'emoji', 'name': 'love_letter'}]}]}], 'reactions': [{'name': 'heart', 'users': ['U01UTGRMGEQ'], 'count': 1}]}, {'client_msg_id': '9726729a-a6c4-4854-94c6-87f6684f884a', 'type': 'message', 'text': 'Mình upload file làm hồi nãy lên cho mọi người tham khảo nha ạ. Hy vọng giúp được mọi người!  <!channel>\n<https://drive.google.com/file/d/1M3GA-wsi4v3H9AWnQ_fR2BOyj8AebWZ5/view?usp=sharing>', 'user': 'U01VBGPP1EU', 'ts': '1621659513.012100',  ...
# Channel ID: C021KLB0DSB - Channel Name: discuss-group3
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216287.011100', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '63ad890b-9088-4130-aa53-c893b7d93bce', 'type': 'message', 'text': 'Tuần này chưa thấy bài nộp của bạn <@U01UJ9P1S3X> :eyes:', 'user': 'U01V00LQ7EV', 'ts': '1622216195.010600', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': '=P8ET', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Tuần này chưa thấy bài nộp của bạn '}, {'type': 'user', 'user_id': 'U01UJ9P1S3X'}, {'type': 'text', 'text': ' '}, {'type': 'emoji', 'name': 'eyes'}]}]}], 'thread_ts': '1622216195.010600', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1622216227.010800', 'reply_users': ['U01UJ9P1S3X'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'joy', 'users': ['U01UJ9P1S3X'], 'count': 1}]}, {'client_msg_id': '3407628b-3811-48b9-97c7-39b9fefda58f', 'type': 'message', 'text': 'thật ngại khi em toàn hỏi ngu :joy: nhưng cho em hỏi, LEFT JOIN và RIGHT JOIN thì làm sao mình biết được bảng nào nằm bên trái, bảng nào bên phải để sử dụng đúng ạ? Ý em là vị trí ấy ạ', 'user': 'U01V00KHHHP', 'ts': '1622214195.009100', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'DhxrT', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'thật ngại khi em toàn hỏi ngu '}, {'type': 'emoji', 'name': 'joy'}, {'type': 'text', 'text': ' nhưng cho em hỏi, LEFT JOIN và RIGHT JOIN thì làm sao mình biết được bảng nào nằm bên trái, bảng nào bên phải để sử dụng đúng ạ? Ý em là vị trí ấy ạ'}]}]}], 'thread_ts': '1622214195.009100', 'reply_count': 4, 'reply_users_count': 2, 'latest_reply': '1622253217.000500', 'reply_users': ['U01V00LQ7EV', 'U01V00KHHHP'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}]}, {'type': 'message', 'text': 'mn ơi, em gặp lỗi này khi chạy sql. Em đã thử 1 số cách trên Google mà vẫn chưa đc. Không biết làm sao để khắc phục lỗi này mn nhỉ :sob:', 'files': [{'id': 'F023CDRMX8T', 'created': 1622194553, 'timestamp': 1622194553, 'name': 'Screen Shot 2021-05-28 at 16.34.46.png', 'title': 'Screen Shot 2021-05-28 at 16.34.46.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01V00KHHHP', 'editable': False, 'size': 125562, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023CDRMX8T/screen_shot_2021-05-28_at_16.34.46.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023CDRMX8T/download/screen_shot_2021-05-28_at_16.34.46.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_360.png', 'thumb_360_w': 360, 'thumb_360_h': 118, 'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_480.png', 'thumb_480_w': 480, 'thumb_480_h': 157, 'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_720.png', 'thumb_720_w': 720, 'thumb_720_h': 236, 'thumb_800': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at_16.34.46_800.png', 'thumb_800_w': 800, 'thumb_800_h': 262, 'thumb_960': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023CDRMX8T-12b5f6b4fe/screen_shot_2021-05-28_at ...
# Channel ID: C021KLB90GP - Channel Name: discuss-group4
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216298.007900', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'client_msg_id': '62f7d6fc-81f6-4f11-8d40-9b8048ac8205', 'type': 'message', 'text': '• Hi mn, mn làm assignment 4 thế nào rồi? \n• Trong quá trình làm mình có để ý có một vấn đề liên quan đến những bạn đã nộp bài. Ví dụ như bạn "*Việt Hồng Chu*" đã nộp bài ở Assignment 3 rồi nhưng khi query những Learner chưa làm Assignment 3 thì lai có thông tin bạn. Mình kiểm tra thì do chỗ code lấy thông tin "*3. Message Data*" đang lọc theo điều kiện phải có key "*client_msg_id*". \n• Mình có tìm hiểu thì do những message nào có attachments thì trong file JSON get từ API sẽ không có thông tin key "*client_msg_id*".  Các bạn lưu ý điều này nhé. Và mình cũng bổ sung vấn đề này là một trong những rules khi submit hay re-sumit các Assignment.  Không biết bạn nào gặp trường hợp này không? và có cách lý giải khác thì bổ sung giúp mình nhé. Cảm ơn mn', 'user': 'U01UMJ36QD9', 'ts': '1622212430.007500', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01UMJ36QD9', 'ts': '1622212532.000000'}, 'blocks': [{'type': 'rich_text', 'block_id': 'OQc6i', 'elements': [{'type': 'rich_text_list', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Hi mn, mn làm assignment 4 thế nào rồi? '}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Trong quá trình làm mình có để ý có một vấn đề liên quan đến những bạn đã nộp bài. Ví dụ như bạn "'}, {'type': 'text', 'text': 'Việt Hồng Chu', 'style': {'bold': True}}, {'type': 'text', 'text': '" đã nộp bài ở Assignment 3 rồi nhưng khi query những Learner chưa làm Assignment 3 thì lai có thông tin bạn. Mình kiểm tra thì do chỗ code lấy thông tin "'}, {'type': 'text', 'text': '3. Message Data', 'style': {'bold': True}}, {'type': 'text', 'text': '" đang lọc theo điều kiện phải có key "'}, {'type': 'text', 'text': 'client_msg_id', 'style': {'bold': True}}, {'type': 'text', 'text': '". '}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mình có tìm hiểu thì do những message nào có attachments thì trong file JSON get từ API sẽ không có thông tin key "'}, {'type': 'text', 'text': 'client_msg_id', 'style': {'bold': True}}, {'type': 'text', 'text': '".  Các bạn lưu ý điều này nhé. Và mình cũng bổ sung vấn đề này là một trong những rules khi submit hay re-sumit các Assignment.  Không biết bạn nào gặp trường hợp này không? và có cách lý giải khác thì bổ sung giúp mình nhé. Cảm ơn mn'}]}], 'style': 'bullet', 'indent': 0}]}]}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856873.000400', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621825588.000200', 'user': 'U01V00P4S2V', 'text': '<@U01V00P4S2V> has joined the channel', 'inviter': 'U01UJKRQM2R'}, {'type': 'message', 'text': 'em có một thắc mắc nhỏ là bài python ở github làm sao mọi người edit được và viết code vào trong file đó luôn ạ O.o lúc em chọn edit thì nó ra nguyên một đoạn code dài ngoằng luôn', 'files': [{'id': 'F022BEG0E31', 'created': 1621768491, 'timestamp': 1621768491, 'name': 'Screen Shot 2021-05-23 at 6.14.22 PM.png', 'title': 'Screen Shot 2021-05-23 at 6.14.22 PM.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01UMBZHU2W', 'editable': False, 'size': 107235, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F022BEG0E31/screen_shot_2021-05-23_at_6.14.22_pm.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F022BEG0E31/download/screen_shot_2021-05-23_at_6.14.22_pm.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F022BEG0E31-a9219d3ac5/screen_shot_2021-05-2 ...
# Channel ID: C02204B2CD6 - Channel Name: atom-week2
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216235.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856836.001100', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756548.000800', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621700416.000400', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_topic', 'ts': '1621074535.001700', 'user': 'U01BE2PR6LU', 'text': '<@U01BE2PR6LU> set the channel topic: TOPIC: Python Basics &amp; Git', 'topic': 'TOPIC: Python Basics &amp; Git'}, {'type': 'message', 'subtype': 'tombstone', 'text': 'This message was deleted.', 'user': 'USLACKBOT', 'hidden': True, 'ts': '1621043934.000600', 'thread_ts': '1621043934.000600', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621044089.001100', 'reply_users': ['U01UTGVPE7N', 'U01UJ9M3P1T'], 'is_locked': False, 'subscribed': False}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621034026.000200', 'user': 'U01UMBX2X18', 'text': '<@U01UMBX2X18> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621015159.000500', 'user': 'U01V00LQ7EV', 'text': '<@U01V00LQ7EV> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621002632.000200', 'user': 'U01UJ9NKX8D', 'text': '<@U01UJ9NKX8D> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620828107.000200', 'user': 'U01U6JQB695', 'text': '<@U01U6JQB695> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620705346.000200', 'user': 'U01UJ9M3P1T', 'text': '<@U01UJ9M3P1T> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620632101.000400', 'user': 'U01UTGS5ZNY', 'text': '<@U01UTGS5ZNY> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620620238.000200', 'user': 'U020P877V88', 'text': '<@U020P877V88> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620578053.000400', 'user': 'U01UTGVPE7N', 'text': '<@U01UTGVPE7N> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620536064.000200', 'user': 'U01UMC08KL2', 'text': '<@U01UMC08KL2> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620478689.003200', 'user': 'U01V00P4S2V', 'text': '<@U01V00P4S2V> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620447242.002200', 'user': 'U01UMJ451V1', 'text': '<@U01UMJ451V1> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620440115.002000', 'user': 'U01UQGZHSTZ', 'text': '<@U01UQGZHSTZ> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620440097.001800', 'user': 'U01UTGT8CVA', 'text': '<@U01UTGT8CVA> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439747.001600', 'user': 'U01UJ9MUADT', 'text': '<@U01UJ9MUADT> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439697.001400', 'user': 'U01UJ9PRT5K', 'text': '<@U01UJ9PRT5K> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439668.001200', 'user': 'U01UEJFMUSJ', 'text': '<@U01UEJFMUSJ> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439648.001000', 'user': 'U01UMJ36QD9', 'text': '<@U01UMJ36QD9> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439633.000800', 'user': 'U01UMBW8G8J', 'text': '<@U01UMBW8G8J> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1620439592.00 ...
# Channel ID: C0220KU9399 - Channel Name: discuss-group1
# {'ok': True, 'messages': [{'type': 'message', 'text': 'Em có một thắc mắc khi làm phép tính trong SQL.\nEm có dùng công thức để tỉnh % learner đã nôp 1,2,3 và dùng thử công thức đầu tiên (tuy nhiên không ra kết quả) mong muốn, sau đó e đổi lại qua công thức thứ 2 (thì kết quả mới trả ra).\nCho em hỏi sự khác nhau giữa hai công thức là gì ạ?', 'files': [{'id': 'F0231AV2B71', 'created': 1622354917, 'timestamp': 1622354917, 'name': 'Screen Shot 2021-05-30 at 13.03.49.png', 'title': 'Screen Shot 2021-05-30 at 13.03.49.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01UEJFMUSJ', 'editable': False, 'size': 107546, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F0231AV2B71/screen_shot_2021-05-30_at_13.03.49.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F0231AV2B71/download/screen_shot_2021-05-30_at_13.03.49.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_360.png', 'thumb_360_w': 360, 'thumb_360_h': 229, 'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_480.png', 'thumb_480_w': 480, 'thumb_480_h': 305, 'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_720.png', 'thumb_720_w': 720, 'thumb_720_h': 458, 'thumb_800': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_800.png', 'thumb_800_w': 800, 'thumb_800_h': 509, 'thumb_960': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_960.png', 'thumb_960_w': 960, 'thumb_960_h': 611, 'thumb_1024': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0231AV2B71-c8570c1e8a/screen_shot_2021-05-30_at_13.03.49_1024.png', 'thumb_1024_w': 1024, 'thumb_1024_h': 652, 'image_exif_rotation': 1, 'original_w': 1089, 'original_h': 693, 'thumb_tiny': 'AwAeADC/0pwpvHelAFAxcUYpaKBCYpaKKAGYPrilGfUflQ3WlP3hQMWilzRmgQlFLmjNAH//2Q==', 'permalink': 'https://datacracy.slack.com/files/U01UEJFMUSJ/F0231AV2B71/screen_shot_2021-05-30_at_13.03.49.png', 'permalink_public': 'https://slack-files.com/T01B7SGGMLJ-F0231AV2B71-65863a7679', 'is_starred': False, 'has_rich_preview': False}, {'id': 'F023D1TGT1T', 'created': 1622354922, 'timestamp': 1622354922, 'name': 'Screen Shot 2021-05-30 at 13.04.41.png', 'title': 'Screen Shot 2021-05-30 at 13.04.41.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01UEJFMUSJ', 'editable': False, 'size': 106456, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023D1TGT1T/screen_shot_2021-05-30_at_13.04.41.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023D1TGT1T/download/screen_shot_2021-05-30_at_13.04.41.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023D1TGT1T-d076f8d3d7/screen_shot_2021-05-30_at_13.04.41_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023D1TGT1T-d076f8d3d7/screen_shot_2021-05-30_at_13.04.41_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023D1TGT1T-d076f8d3d7/screen_shot_2021-05-30_at_13.04.41_360.png', 'thumb_360_w': 360, 'thumb_360_h': 237, 'thumb_480': 'https://files.slack.com/files ...
# Channel ID: C0226D3LEQ4 - Channel Name: atom-week3
# ...
# Channel ID: C022Q7TGRLG - Channel Name: discuss-group2
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622216273.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'text': "Chào moi người, moi người làm assignment 4 có găp lỗi 'np' is not defined không ạ\nĐến bài này mình hơi bị ngôp vì thấy qúa nhiều mà không biết bát đầu từ đâu luôn.", 'files': [{'id': 'F0234JN4F8B', 'created': 1622044678, 'timestamp': 1622044678, 'name': 'Capture9.PNG', 'title': 'Capture9.PNG', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01UQGZHSTZ', 'editable': False, 'size': 17233, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F0234JN4F8B/capture9.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F0234JN4F8B/download/capture9.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_360.png', 'thumb_360_w': 360, 'thumb_360_h': 107, 'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_480.png', 'thumb_480_w': 480, 'thumb_480_h': 143, 'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_720.png', 'thumb_720_w': 720, 'thumb_720_h': 214, 'thumb_800': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0234JN4F8B-3581f89b76/capture9_800.png', 'thumb_800_w': 800, 'thumb_800_h': 238, 'original_w': 831, 'original_h': 247, 'thumb_tiny': 'AwAOADCkDgdKN3sKQcUuf84oAM59KPypCaSgBc/SjNGPpRigD//Z', 'permalink': 'https://datacracy.slack.com/files/U01UQGZHSTZ/F0234JN4F8B/capture9.png', 'permalink_public': 'https://slack-files.com/T01B7SGGMLJ-F0234JN4F8B-bbce93d641', 'is_starred': False, 'has_rich_preview': False}], 'upload': False, 'blocks': [{'type': 'rich_text', 'block_id': '32b', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': "Chào moi người, moi người làm assignment 4 có găp lỗi 'np' is not defined không ạ\nĐến bài này mình hơi bị ngôp vì thấy qúa nhiều mà không biết bát đầu từ đâu luôn."}]}]}], 'user': 'U01UQGZHSTZ', 'display_as_bot': False, 'ts': '1622044778.001600', 'thread_ts': '1622044778.001600', 'reply_count': 3, 'reply_users_count': 3, 'latest_reply': '1622127184.000400', 'reply_users': ['U01V00JK9LH', 'U01VBGPP1EU', 'U01UQGZHSTZ'], 'is_locked': False, 'subscribed': False}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621856861.000200', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621756585.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621696690.007000', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'thread_broadcast', 'text': 'Token bị inactive. Bạn có thể tự tạo token qua Slack API. Hoặc xài cái token mới này nha\n<https://datacracy.slack.com/archives/C01B4PVGLVB/p1621649041051100?thread_ts=1621619617.042600&amp;cid=C01B4PVGLVB>', 'user': 'U01BE2PR6LU', 'ts': '1621659457.006200', 'thread_ts': '1621659367.005900', 'root': {'type': 'message', 'text': 'Xin chào moi người, có ai gặp những lõi này không ạ?', 'files': [{'id': 'F022AB7T38X', 'created': 1621659359, 'timestamp': 1621659359, 'name': 'Capture8.PNG', 'title': 'Capture8.PNG', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01UQGZHSTZ', 'editable':  ...
# Channel ID: C022RRWQ6US - Channel Name: atom-assignment4
# {'ok': True, 'messages': [{'client_msg_id': '5f2de85e-dc4a-4a8c-bfe9-c959a4e9bc0d', 'type': 'message', 'text': 'Xin chào cả nhà, em xin phép gửi bài assignment 4 đã revised ở link <https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%204_Link%20of%20assignment%20for%20peer%20review|này>. Phần To-do-6 về code em vẫn lạch bạch nên đã tham khảo ở bài của chị Thảo Nguyên và bạn Huỳnh Anh rất nhiều. Bài làm của cả 2 đều rất hay và dễ hiểu ạ :smiling_face_with_tear:', 'user': 'U01UTGRMGEQ', 'ts': '1622381656.003700', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01UTGRMGEQ', 'ts': '1622382090.000000'}, 'attachments': [{'text': '```\n<https://colab.research.google.com/drive/1-1ZeGKGqYR-pPLgjgkAuX9o3MKj-8dkM?usp=sharing>\n\n```', 'title': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%204_Link%20of%20assignment%20for%20peer%20review | WEEK 4_Link of assignment for peer review>', 'footer': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh|nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh>', 'id': 1, 'footer_icon': 'https://slack.github.com/static/img/favicon-neutral.png', 'color': '24292f', 'mrkdwn_in': ['text'], 'fallback': '<https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%204_Link%20of%20assignment%20for%20peer%20review | WEEK 4_Link of assignment for peer review>', 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%204_Link%20of%20assignment%20for%20peer%20review', 'is_app_unfurl': True}], 'blocks': [{'type': 'rich_text', 'block_id': 'HzZ', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Xin chào cả nhà, em xin phép gửi bài assignment 4 đã revised ở link '}, {'type': 'link', 'url': 'https://github.com/nguyenhonghanh2511/datacracy-atom-Nguyen-T-Hong-Hanh/blob/main/WEEK%204_Link%20of%20assignment%20for%20peer%20review', 'text': 'này'}, {'type': 'text', 'text': '. Phần To-do-6 về code em vẫn lạch bạch nên đã tham khảo ở bài của chị Thảo Nguyên và bạn Huỳnh Anh rất nhiều. Bài làm của cả 2 đều rất hay và dễ hiểu ạ '}, {'type': 'emoji', 'name': 'smiling_face_with_tear'}]}]}], 'reactions': [{'name': 'clap', 'users': ['U01UEJFMUSJ'], 'count': 1}]}, {'client_msg_id': 'b8d26ef6-e636-44d9-a6cb-ab9ffd9b5fb5', 'type': 'message', 'text': 'Mặc dù muộn nhưng em xin phép nộp bài assignment 4 ạ. Còn todo7 em sẽ cố gắng hoàn thành nốt ạ.\nGit link: <https://github.com/nhduonng2803/Datacracy-atom-nhduong/tree/main/week04>', 'user': 'U01UEJFMUSJ', 'ts': '1622354518.001100', 'team': 'T01B7SGGMLJ', 'blocks': [{'type': 'rich_text', 'block_id': 'LrkG', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mặc dù muộn nhưng em xin phép nộp bài assignment 4 ạ. Còn todo7 em sẽ cố gắng hoàn thành nốt ạ.\nGit link: '}, {'type': 'link', 'url': 'https://github.com/nhduonng2803/Datacracy-atom-nhduong/tree/main/week04'}]}]}], 'reactions': [{'name': 'clap', 'users': ['U01UTGRMGEQ'], 'count': 1}, {'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}]}, {'client_msg_id': 'cecc242e-b0d2-4fa3-94a9-815516dc6238', 'type': 'message', 'text': 'Chào buổi sáng cả nhà, em gửi <https://github.com/phanlinh0803/atom-assignments/blob/PhanLinh-assignment-04/ATOM_%7C_Phan_Linh_Home_Assignment_04.ipynb|assigment 04> của em ạ  :woman-gesturing-ok:', 'user': 'U01KDQJ9FCG', 'ts': '1622250908.016000', 'team': 'T01B7SGGMLJ', 'attachments': [{'text': '```\n{\n  "nbformat": 4,\n  "nbformat_minor": 0,\n  "metadata": {\n    "colab": {\n      "name": "ATOM | Phan-Linh-Home Assignment 04.ipynb",\n      "provenance": [],\n      "collapsed_sections": [],\n      "authorship_tag": "ABX9TyMxg9jQGzxp5S4pNNaa8045",\n      "include_colab_link": true\n    },\n    "kernelspec": {\n      "name": "python3",\n      "display_name": "Python 3"\n    },\n    "language_info": {\n      "name": "python"\n    }\n  },\n  "cells": [\n    {\n  ...
# Channel ID: C022Y1FUETE - Channel Name: atom-week4
# {'ok': True, 'messages': [{'type': 'message', 'subtype': 'channel_join', 'ts': '1622354729.000200', 'user': 'U01UEJFMUSJ', 'text': '<@U01UEJFMUSJ> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1622265919.000200', 'user': 'U01V00KHHHP', 'text': '<@U01V00KHHHP> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1622226772.000500', 'user': 'U01UTGVPE7N', 'text': '<@U01UTGVPE7N> has joined the channel'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1622216248.000300', 'user': 'U0226MQ73MJ', 'text': '<@U0226MQ73MJ> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1622124901.000200', 'user': 'U01UJ9P1S3X', 'text': '<@U01UJ9P1S3X> has joined the channel'}, {'type': 'message', 'text': 'PK - FK. User ID. Creator', 'files': [{'id': 'F023PTHSUBS', 'created': 1621963081, 'timestamp': 1621963081, 'name': 'image.png', 'title': 'image.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01BE2PR6LU', 'editable': False, 'size': 141408, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023PTHSUBS/image.png', 'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F023PTHSUBS/download/image.png', 'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_360.png', 'thumb_360_w': 360, 'thumb_360_h': 172, 'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_480.png', 'thumb_480_w': 480, 'thumb_480_h': 230, 'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_720.png', 'thumb_720_w': 720, 'thumb_720_h': 344, 'thumb_800': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_800.png', 'thumb_800_w': 800, 'thumb_800_h': 383, 'thumb_960': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_960.png', 'thumb_960_w': 960, 'thumb_960_h': 459, 'thumb_1024': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F023PTHSUBS-eada9e7ccb/image_1024.png', 'thumb_1024_w': 1024, 'thumb_1024_h': 490, 'original_w': 1215, 'original_h': 581, 'thumb_tiny': 'AwAWADCoxJPf8aZ+VPbOeRj8c0zP1oAOPX9KOP8AIoz9aTPuaACjNGTRmgBxIIyQB9KTj0oP3RTaAF4o4pKKAF4o+lJS0Af/2Q==', 'permalink': 'https://datacracy.slack.com/files/U01BE2PR6LU/F023PTHSUBS/image.png', 'permalink_public': 'https://slack-files.com/T01B7SGGMLJ-F023PTHSUBS-9b3a2084b1', 'is_starred': False, 'has_rich_preview': False}], 'upload': False, 'blocks': [{'type': 'rich_text', 'block_id': 'WyI', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'PK - FK. User ID. Creator'}]}]}], 'user': 'U01BE2PR6LU', 'display_as_bot': False, 'ts': '1621963197.001800'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1621963031.001400', 'user': 'U01V082PLN5', 'text': '<@U01V082PLN5> has joined the channel', 'inviter': 'U01BE2PR6LU'}, {'type': 'message', 'text': '<!channel> LOGIC LẤY NGƯỜI NỘP BÀI SỚM NHẤT\n-----\nCâu hỏi hay nên post qua cho mọi ng tham khảo nha\nFrom <@U01V082PLN5>\n&gt; Mọi người ơi cho em hỏi câu SQL 6.1b (Learners nào nộp bài sớm nhất trong Assignment 1,2,3) với ạ. Vì những criteria em đang nghĩ để define người nộp bài sớm nhất bao gồm: DataCracy_role: ‘Learner’, github_link: IS NOT NULL, MIN(msg_timestamp). Nhưng result query ở assignment 2 &amp; 3 expected output ko giống như những gì thực sự đã diễn ra ạ. Trong thực tế thì bạn Quân là người nộp bài nhanh nhất cả assign2&amp;3 nhưng nếu query theo cách của em sẽ có output khác như ...
# Channel ID: C023UJGMDND - Channel Name: atom-assignment5
# {'ok': False, 'error': 'not_in_channel'}
# Channel ID: C0245PZUFSL - Channel Name: atom-week5
# {'ok': False, 'error': 'not_in_channel'}

# %%
msg_df = pd.DataFrame(msg_dict)
#msg_df = msg_df.replace('', np.nan) # -> replace khoảng trắng bằng giá trị NULL (nan)
msg_df.tail()
# Out:
#       channel_id  ...                     github_link
# 285  C022RRWQ6US  ...
# 286  C022RRWQ6US  ...
# 287  C022RRWQ6US  ...  https://github.com/anhdanggit/
# 288  C022Y1FUETE  ...
# 289  C022Y1FUETE  ...
#
# [5 rows x 8 columns]

# %%
msg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        290 non-null    object
#  1   msg_id            290 non-null    object
#  2   msg_ts            290 non-null    datetime64[ns]
#  3   user_id           290 non-null    object
#  4   latest_reply      290 non-null    datetime64[ns]
#  5   reply_user_count  290 non-null    int64
#  6   reply_users       290 non-null    object
#  7   github_link       290 non-null    object
# dtypes: datetime64[ns](2), int64(1), object(5)
# memory usage: 18.2+ KB

# %% [markdown]
# ### 0.4. DataCracy Info
# * **Data do dự án tự collect - File CSV (trích xuất từ Google Spreadsheet)**: Danh sách thành viên được phân theo vị trí (mentors, learners, BTC)
# * Trong cùng folder Github `assignment_4`

# %%
dtc_groups = pd.read_csv('datacracy_groups.csv')
dtc_groups.head()
# Out:
#                 name DataCracy_role
# 0           slackbot            BTC
# 1     loclexuan26392            BTC
# 2           locle.ds            BTC
# 3     maianhdang.ftu            BTC
# 4  huyenhoang.design            BTC

# %% [markdown]
# ## STEP 1: NHU CẦU & MỤC ĐÍCH
# > Đặt mình vào vị trí người chủ, bạn quan tâm đến điều gì?
#
# * Quan trọng nhất của mọi Data Solution, là bắt đầu từ nhu cầu, mục đích và câu hỏi lớn của Clients (người chủ).
# * Chính từ những câu hỏi lớn này, ta có thể khoanh vùng thông tin nào quan trọng, ta muốn đạt được điều gì?

# %% [markdown]
# ### TODO#1: Requirements
# Tự trả lời các câu hỏi sau, từ góc nhìn của bạn (đặt mình vào vị trí bạn là co-founder của dự án DataCracy):
# 1. Mục đích của lớp học Atom là gì?
# 2. BTC sẽ quan tâm đến những chủ đề/quy trình gì để đạt được Mục Đích trong (1)?
# 3. Làm sao để đo lường các điểm trong (2)? => Metrics?
# 4. Dựa vào các data đã có như liệt kê trong `STEP 0`:
#   * Chỉ dùng những data sẵn có, ta có thể đo lường và thiết kế những metrics nào bạn đã liệt kê trong (3)?
#   * Tham khảo Slack API và hình dung về các thông tin DataCracy có khả năng thu thập, bạn sẽ đề xuất DataCracy thu thập thêm những thông tin gì?

# %%
## Điền vào bên dưới câu trả lời của bạn
''' 
REQUIREMENTS
---
1. Để học viên có thể xử lý luợng lớn data bằng code, cụ thể là python
2. Học cách xử lý dữ liệu bằng python, học viên tham dự lớp học và làm đủ bài tập
3. Số lượng học viên tham dự, số bài tập submit theo từng tuần
4. Những metrics có thể đo được : số học viên tham dự, số lượng/phần trăm bài submit theo từng tuần và tổng
'''

# %% [markdown]
# ## STEP 2: TỔ CHỨC THÔNG TIN
# > Thu thập và hệ thống lại các thông tin

# %%
## Hints: info() để check các thông tin (Column), số dòng (Count), và Data Type của mỗi cột
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       75 non-null     object
#  1   name          75 non-null     object
#  2   display_name  75 non-null     object
#  3   real_name     75 non-null     object
#  4   title         75 non-null     object
#  5   is_bot        75 non-null     bool
# dtypes: bool(1), object(5)
# memory usage: 3.1+ KB

# %% [markdown]
# ### TODO#2: List Down
# Trả lời các câu hỏi sau:
# 1. Có những thông tin gì trong các bảng data ở `STEP 0`? Ý nghĩa của mỗi trường (Column). `Hints: Đọc thêm Slack API để hiểu ý nghĩa data trả về`
# 2. Data Type của mỗi trường
# 3. Có NULL không? (Non-Null Count <> entries)
#
# * Ta sẽ dùng công cụ: [QuickDBD](https://www.quickdatabasediagrams.com/) cho Assignment này => Tham khảo Sample lúc mở tool
# * Copy điền đoạn text vào tools

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Điền vào bên dưới câu trả lời của bạn
## Bên dưới là ví dụ của bảng user_df (Điền tiếp các bản còn lại)
''' 
# Dtype obj: object -> string, bool, int, float
# NULL - Nếu có null count < số entries

# Ví dụ  bảng user_df 
user_df
-
user_id string
name string
display_name NULL string
real_name string
title NULL string
is_bot bool

# Điền tiếp các bản còn lại
channel_df

channel_id string 
channel_name string
is_channel bool 
creator string
created_at datetime
topic object
purpose object 
num_members  integer

msg_df
channel_id string
msg_id string
msg_ts datetime
user_id string
latest_replay datetime
reply_user_count integer
reply_users object
github_link string

# %% [markdown]
# ## STEP 3: NGUYÊN TẮC CẦN ÁP DỤNG

# %% [markdown]
# ### TODO#3: Rules & Logics
# Dựa vào các kiến nghị `TODO#1` và Quan sát ở `TODO#2`, bạn có những đề xuất gì về rules trong vận hành để cải thiện thông tin và quan sát?
#
# #### Về mặt vận hành
# > Rules gì cần áp dụng cho cách thức nhập data?
#
# **Một số gợi ý**
# 1. Rules để cải thiện tỷ lệ NULL trong các bạn? (Ví dụ: Bắt buộc nhập các thông tin trên Slack? Có cần thiết không?)
# 2. Làm sao để xác định message nào là bài submit assigment? Message nào là review? Message vào là các nội dung không liên quan? (Ví dụ: Users để tag #submit, #review?)
# 3. ...
#
# #### Về mặt data
# > Logics gì cần áp dụng để kiểm tra sự hợp lý của Data?
#
# **Một số gợi ý**
# 1. Hai users trùng tên?
# 2. Ngày latest reply > ngày post?
# 3. Ngày post trong năm 2021 (sau khi dự án DataCracy thành lập)
# 4. Mentor Group nào sẽ chỉ post trong channel discussion của group đó?
# 5. ...
#
# Bạn có thể đưa các đề xuất để đưa vào vận hành nhằm cải thiện data và giúp bạn đo lường theo dõi các metrics đã được liệt kể trong `TODO#1`

# %%
## Điền vào bên dưới câu trả lời của bạn
''' 
RULES
---
1. 
2. 
3. 
4. 
'''

# %%
## Điền vào bên dưới câu trả lời của bạn
''' 
LOGICS
---
1. 
2. 
3. 
4. 
'''

# %% [markdown]
# ## STEP 4: TỔ CHỨC BẢNG - PRIMARY KEYS

# %%
## Hints: nunique() để check số giá trị unique của từng trường
user_df.nunique()
# Out:
# user_id         74
# name            74
# display_name    48
# real_name       72
# title            5
# is_bot           2
# dtype: int64

# %% [markdown]
# ### TODO#4: Tables & PK
# 1. Nhìn lại diagram của `TODO#2` trong Quick DBD Diagram: Có bảng nào bạn nghĩ nên gộp lại, hay tách ra không? Vì sao?
# 2. Tìm Primary Key (PK): Unique cho từng dòng và Không NULL
# > Primary Key (PK) là trường giá trị/ID unique cho mỗi dòng của bảng. Hay nói cách khác, không có hai dòng trùng lặp (duplicate ID).
# * Fun fact để nhớ: Thử tưởng tượng nếu 2 người không quen biết, có cùng Số TK Ngân hàng :((((

# %%
## Copy lại phần text của TODO#2
## Đặt PK bên cạnh col bạn chọn làm PK
''' 
# Dtype obj: object -> string, bool, int, float
# NULL - Nếu có null count < số entries

# Ví dụ  bảng user_df 
user_df
-
user_id string PK
name string
display_name NULL string
real_name string
title NULL string
is_bot bool

# Điền tiếp các bản còn lại
channel_id string PK
channel_name string
is_channel bool 
creator string FK
created_at datetime
topic object
purpose object 
num_members  integer

msg_df
channel_id string FK
msg_id string PK
msg_ts datetime
user_id string FK
latest_replay datetime
reply_user_count integer
reply_users object
github_link string

# %% [markdown]
# ## STEP 5: MỐI QUAN HỆ GIỮA CÁC BẢNG

# %% [markdown]
# ### TODO#5: FK & Mapping
# Như đã giới thiệu ở phần Concept, keys quan trọng trong Relational DB vì nó thể hiện mối quan hệ giữa các bạn, thông qua key, cho phép ta nối các bảng với nhau.
# Bây giờ ta sẽ đi tìm FK (Foreign Key):
# > Foreign Key: Là các keys nằm trong một bảng để liên kết với PK trong bảng khác
#
# 1. Đâu là các ID trong bảng, nhưng không phải là PK (do thoả điều kiện unique)?
# 2. Các ID này dẫn đến PK nào trong các bảng còn lại?
# 3. Trong các key được nối với nhau, xác định kiểu quan hệ:
#   * n:1 - PK ở bảng gốc lặp lại nhiều lần (nhiều dòng) ở bản chứa FK
#   * 1:1 - PK ở bảng gốc chỉ nối với 1 dòng
#
# **Ví dụ:** `channel_id string FK >- channel_df.channel_id`

# %%
## Copy lại phần text của TODO#2
## Đặt FK bên cạnh col bạn chọn làm FK
## Và thể hiện mối quan hệ bằng: id >- bảng_gốc.id (FK là PK trong bảng gốc)
''' 
# Ví dụ  bảng user_df 
user_df
-
user_id string 
name string
display_name NULL string
real_name string
title NULL string
is_bot bool

msg_df
-
channel_id string FK >- channel_df.channel_id #Rel: n:1

# Điền tiếp các bản còn lại
channel_df

channel_id string 
channel_name string
is_channel bool 
creator string FK --> user_df.user_id #Rel: n:1
created_at datetime
topic object
purpose object 
num_members  integer

msg_df

channel_id string FK
msg_id string
msg_ts datetime
user_id string FK user_df.user_id #Rel: n:1
latest_replay datetime
reply_user_count integer
reply_users object
github_link string

# %% [markdown]
# ## STEP 6: DIAGRAM & TEST
# Sau khi làm hết `TODO#5` bạn sẽ được 1 DB Diagram như trong sample mẫu bên dưới (Sample này không phải của DataCracy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Test Database Design by SQL
# * Để giúp các bạn làm quen với việc thao tác trên SQL, ta sử dụng thư việc duckdb, cho phép ta thao tác với Data trên Python bằng SQL: https://duckdb.org/2021/05/14/sql-on-pandas.html
# * Để hiểu các code SQL bên dưới, tham khảo [SQL Basic Cheatsheet](https://learnsql.com/blog/sql-basics-cheat-sheet/), xem các phần:
#   * Querying Single Table
#   * Aliases
#   * Filtering
#   * Querying Multiple Tables: Các dạng Join
#   * Aggregation Functions
#
# * Dựa vào DB Diagram bạn đã vẽ, sẽ giúp bạn dễ dàng theo dõi hơn trong việc join và xử lý data

# %%
## Đoạn code dưới join 2 bảng user_df vằ dtc_groups bằng key name => Tạo thành bảng members_df
SQL_dim_members = '''
-- Để comment trong SQL dùng -- tương đường với ## trong Python
CREATE TABLE members_df AS
SELECT 
  t1.*,
  t2.DataCracy_role
FROM user_df AS t1
JOIN dtc_groups AS t2
ON t1.name = t2.name
'''

# %%
con = duckdb.connect(database=':memory:', read_only=False) # -> Tạo DB connection
# create a table
con.execute(SQL_dim_members) # -> Chạy đoạn lệch SQL
con.execute("SELECT * FROM members_df").fetch_df() # -> In 10 dòng đầu tiên của bảng members_df ra Dataframe
# Out:
#         user_id                name  ... is_bot DataCracy_role
# 0     USLACKBOT            slackbot  ...  False            BTC
# 1   U01AT4T75JB      loclexuan26392  ...  False            BTC
# 2   U01AVDY7JET            locle.ds  ...  False            BTC
# 3   U01BE2PR6LU      maianhdang.ftu  ...  False            BTC
# 4   U01C48T7S1J   huyenhoang.design  ...  False            BTC
# ..          ...                 ...  ...    ...            ...
# 60  U020P6WPAQJ          thuynh.386  ...  False     Mentor_Gr4
# 61  U020P877V88        huongntn2202  ...  False            NaN
# 62  U021TFMH1RU       mquang.151999  ...  False            NaN
# 63  U021Y57RMN1            lamlv723  ...  False            NaN
# 64  U0233KHLM2M  vuthanhdat.contact  ...  False    Learner_Gr4
#
# [65 rows x 7 columns]

# %%
con.execute("SELECT * FROM channel_df LIMIT 5").fetch_df() # -> In 5 dòng đầu tiên của bảng channel_df ra Dataframe
# Out:
#     channel_id  ... num_members
# 0  C01B4PVGLVB  ...          65
# 1  C01BYH7JHB5  ...          12
# 2  C01CAMNCJJV  ...           9
# 3  C01U6P7LZ8F  ...          44
# 4  C01UL6K1C7L  ...          43
#
# [5 rows x 8 columns]

# %%
con.execute("SELECT * FROM msg_df LIMIT 5").fetch_df() # -> In 5 dòng đầu tiên của bảng msg_df ra Dataframe
# Out:
#     channel_id                                msg_id  ... reply_users github_link
# 0  C01B4PVGLVB  da7ab6eb-0b3c-4bd6-a12a-589a12c56604  ...         NaN
# 1  C01B4PVGLVB  e289e819-5ec8-472b-8a48-900ef1874750  ...         NaN
# 2  C01B4PVGLVB  07bbab9c-a507-4249-ad4e-c440be810076  ...         NaN
# 3  C01B4PVGLVB  0b9a47d9-900e-4dcf-af8f-8897e6fe6fdd  ...         NaN
# 4  C01B4PVGLVB  DEBF1A3C-17AA-4D53-AC27-1FE0884243DB  ...         NaN
#
# [5 rows x 8 columns]

# %%
## Đoạn code dưới: Theo từng channel, count số message (phải join với bảng channel_df để lấy tên channel)
SQL = '''
SELECT 
  t2.channel_name,
  COUNT(DISTINCT t1.msg_id) AS msg_cnt
FROM msg_df AS t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
GROUP BY t2.channel_name 
ORDER BY COUNT(DISTINCT t1.msg_id) DESC
'''
con.execute(SQL).fetch_df()
# Out:
#         channel_name  msg_cnt
# 0            general       47
# 1   atom-assignment1       42
# 2   atom-assignment2       42
# 3   atom-assignment3       39
# 4     discuss-group1       32
# 5   atom-assignment4       26
# 6     discuss-group3       18
# 7      topics-python       13
# 8     discuss-group4       12
# 9         atom-week1        6
# 10    discuss-group2        6
# 11  topics-materials        3
# 12        atom-week3        2
# 13        atom-week4        2

# %%
## Đoạn code dưới: Lấy top 3 mentors post nhiều message nhất trong discuss-group của các nhóm
SQL = '''
WITH msg_cnt AS ( ------------- > (1) Chain SQL: tạo bảng tạm thời msg_cnt: count số msg theo user, theo channel
  SELECT 
    user_id,
    channel_id,
    COUNT(msg_id) AS msg_cnt
  FROM msg_df 
  GROUP BY 1, 2
)
SELECT
  t2.real_name,
  t3.channel_name,
  t1.msg_cnt,
  t2.DataCracy_role
FROM msg_cnt AS t1
JOIN members_df AS t2 ------------ > (2) Join msg_count với members_df để lấy tên và role
ON t1.user_id = t2.user_id
JOIN channel_df AS t3 --> (3) Join với channel_df để lấy tên channel
ON t1.channel_id = t3.channel_id
WHERE t2.DataCracy_role LIKE 'Mentor%' ------------- > (4) Filter Mentors
AND t3.channel_name LIKE 'discuss-group%' ---------- > (5) Filter channel discuss theo các group
ORDER BY t1.msg_cnt DESC ---------- > (6) Sẵp xếp theo số msg từ cao xuống thấp
LIMIT 3 ------------> (7) Lấy top 3
'''
con.execute(SQL).fetch_df()
# Out:
#            real_name    channel_name  msg_cnt DataCracy_role
# 0            Phu NDT  discuss-group1       11     Mentor_Gr1
# 1  Nguyễn Quang Long  discuss-group3       10     Mentor_Gr3
# 2        Thuy Nguyen  discuss-group4        4     Mentor_Gr4

# %% [markdown]
# ### TODO#6: SQL
# * Thay đổi các phần trong những đoạn code SQL trên, print kết quả để hiểu về code
# * Tham khảo thêm [SQL Basic Cheatsheet](https://learnsql.com/blog/sql-basics-cheat-sheet/)
# * Và, GOOGLE! + Cùng trao đổi trên Slack
# * Và viết SQL để trả lời các câu hỏi sau:
# ```
#   1. Learners groups nào hoạt động tích cực trên Slack nhất? (tính theo message count)?
#   Learners nào nộp bài sớm nhất trong Assignment 1, 2, 3?
#   2. Learner nào nộp bài trễ nhất trong Assignment 1, 2, 3?
#   3. Learner nào chưa nộp bài Assignment 3?
#   4. Learner nào chưa nộp bất kỳ 1 assignment nào?
#   5. Tỷ lệ % Learner đã nộp assignment 1, 2, 3? (*giả sử có message trong channel atom-assignment, được tính là đã submit*)
#   6. Tỷ lệ % Learner đã submit bài và dc review trong assignment 1, 2, 3?
#   7. Learners theo Group nào có tỷ lệ % hoàn thành bài tập cao nhất?
# ```
# * `[Optional]` Bạn có thể tự đặt thêm bất kỳ câu hỏi nào bạn quan tâm

# %%
SQL_1 = '''
WITH msg_cnt AS ( 
  SELECT 
    user_id,
    channel_id,
    COUNT(msg_id) AS msg_cnt
  FROM msg_df 
  GROUP BY 1, 2
)
SELECT
  t2.real_name,
  t3.channel_name,
  t1.msg_cnt,
  t2.DataCracy_role
FROM msg_cnt AS t1
JOIN members_df AS t2 
ON t1.user_id = t2.user_id
JOIN channel_df AS t3 
ON t1.channel_id = t3.channel_id
WHERE t2.DataCracy_role NOT LIKE 'Mentor%' 
ORDER BY t1.msg_cnt DESC 
LIMIT 1 
'''
con.execute(SQL_1).fetch_df()
# Out:
#             real_name channel_name  msg_cnt DataCracy_role
# 0  Dặng Huỳnh Mai Anh      general       31            BTC

# %%
# Nop bai tre nhat
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment1'
and t1.github_link is not null
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts desc
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#               real_name                  msg_ts github_link
# 0  Nguyen Thi Hong Hanh 2021-05-13 14:09:48.011

# %%
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment2'
and t1.github_link is not null
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts desc
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#               real_name  ...                             github_link
# 0  Nguyen Thi Hong Hanh  ...  https://github.com/nguyenhonghanh2511/
#
# [1 rows x 3 columns]

# %%
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment3'
and t1.github_link is not null
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts desc
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#               real_name                     msg_ts github_link
# 0  Nguyen Thi Hong Hanh 2021-05-30 14:46:39.001800

# %%
# Nop bai som nhat
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment1'
and display_name != 'MAD'
and t1.github_link is not null and t1.github_link != ''
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#              real_name  ...                           github_link
# 0  Dương Phan Nam Hưng  ...  https://github.com/duongphannamhung/
#
# [1 rows x 3 columns]

# %%
# Nop bai som nhat
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment2'
and display_name != 'MAD'
and t1.github_link is not null and t1.github_link != ''
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#    real_name                  msg_ts                       github_link
# 0  Toan Tran 2021-05-12 15:50:48.004  https://github.com/toantran2206/

# %%
# Nop bai som nhat
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment3'
and display_name != 'MAD'
and t1.github_link is not null and t1.github_link != ''
and t3.DataCracy_role NOT LIKE 'Mentor%' 
order by msg_ts
limit 1
'''
con.execute(SQL_2).fetch_df()
# Out:
#               real_name  ...                             github_link
# 0  Nguyen Thi Hong Hanh  ...  https://github.com/nguyenhonghanh2511/
#
# [1 rows x 3 columns]

# %%
# 3. Learner nào chưa nộp bài Assignment 3?
SQL_2 = '''
select t3.real_name, t1.msg_ts, github_link
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name='atom-assignment3'
and display_name != 'MAD'
and t1.github_link = ''
and t3.DataCracy_role NOT LIKE 'Mentor%' 
'''
con.execute(SQL_2).fetch_df()
# Out:
#               real_name                     msg_ts github_link
# 0  Nguyen Thi Hong Hanh 2021-05-30 14:46:39.001800
# 1  Nguyen Thi Hong Hanh 2021-05-16 06:02:30.007400

# %%
# 4. Learner nào chưa nộp bất kỳ 1 assignment nào?
SQL_2 = '''
select distinct t3.real_name, t1.msg_ts, github_link, channel_name
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name in ('atom-assignment3', 'atom-assignment1', 'atom-assignment2')
and display_name != 'MAD'
and t1.github_link = ''
and t3.DataCracy_role NOT LIKE 'Mentor%' 
'''
con.execute(SQL_2).fetch_df()
# Out:
#                real_name  ...      channel_name
# 0   Nguyen Thi Hong Hanh  ...  atom-assignment1
# 1                Linh Vu  ...  atom-assignment1
# 2            Quan Nguyễn  ...  atom-assignment1
# 3          Việt Hồng Chu  ...  atom-assignment1
# 4                  Vy Le  ...  atom-assignment1
# 5              Ha Nguyễn  ...  atom-assignment1
# 6       Anh Ha Van Huỳnh  ...  atom-assignment1
# 7               Hồng Dới  ...  atom-assignment1
# 8         Dinh Tuấn Phạm  ...  atom-assignment1
# 9              Toan Tran  ...  atom-assignment2
# 10  Nguyễn Thị Thu Trang  ...  atom-assignment2
# 11  Nguyen Thi Hong Hanh  ...  atom-assignment3
# 12  Nguyen Thi Hong Hanh  ...  atom-assignment3
#
# [13 rows x 4 columns]

# %%
# 5. Tỷ lệ % Learner đã nộp assignment 1, 2, 3? (*giả sử có message trong channel atom-assignment, được tính là đã submit*)
SQL_2 = ''' 
select (count(distinct real_name) * 100 / (select count(1) from members_df
  where display_name != 'MAD'
 AND DataCracy_role NOT LIKE 'Mentor%')) as ti_le_nop_bai from (
select t3.real_name, t1.msg_ts, github_link, channel_name
from msg_df t1
JOIN channel_df AS t2
ON t1.channel_id = t2.channel_id
JOIN members_df t3
ON t1.user_id=t3.user_id
where t2.channel_name in ('atom-assignment3', 'atom-assignment1', 'atom-assignment2')
and display_name != 'MAD'
and t1.github_link != ''
and t3.DataCracy_role NOT LIKE 'Mentor%') t 
'''
con.execute(SQL_2).fetch_df()
# Out:
#    ti_le_nop_bai
# 0             68

# %%
6. Tỷ lệ % Learner đã submit bài và dc review trong assignment 1, 2, 3?
7. Learners theo Group nào có tỷ lệ % hoàn thành bài tập cao nhất?

# %% [markdown]
# ## Pandas vs. SQL
# * Python Pandas và SQL dù là 2 ngôn ngữ khác nhau, nhưng về cách thức thao tác và chuyển đổi data thì như nhau
# * Tuỳ theo từng tình huống cụ thể mà ta sẽ sử dụng Python Pandas hay SQL
# * Nhưng các bước thao tác/khám phá/tổng hợp data căn bản nhất gồm:
#
# | Thao tác   |     SQL      |  Python | SpreadSheet |
# |------------|-------------|------|----------|
# | Filter/Selection |  WHERE | df['col'] | Filter |
# | Join Data | JOIN | .join() | - |
# | Group Data |    GROUP BY   |   .groupby(col) | Pivot |
# | Summarize | SUM, AVG, MIN, MAX | .sum(), .mean(), .min(), .max() | SUM, MIN, MAX |
#
# * Tìm hiểu cách thao tác bằng Pandas. [Pandas CheatSheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) => Xem các phần:
#   * **Subset(Rows & Columns)**
#   * **Summarize Data**: Để làm các phép tổng hợp, thống kê
#   * **Group Data**: Tương đương với Pivot trong Excel và `GROUP BY` trong SQL
#   * **Combine Data**: Tương đương với `JOIN` trong SQL
#   * **Plot**

# %%
## Ví dụ: Đoạn code (Pandas) sau làm
## 1. Group by channel_id
## 2. Count các message
## 3. Sắp xếp theo thứ tự số message từ cao xuống thấp (ascending=False)
## 4. Filter lấy Top 5
msg_df.groupby('channel_id')['msg_id'].count().sort_values(ascending=False).head(5)
# Out:
# channel_id
# C021FSDN7LJ    42
# C01U6P7LZ8F    42
# C01B4PVGLVB    37
# C0227A51SAY    32
# C0220KU9399    18
# Name: msg_id, dtype: int64

# %%
## Kết quả tương ứng bằng SQL
SQL = '''
  SELECT 
    channel_id,
    COUNT(msg_id) AS msg_cnt
  FROM msg_df 
  GROUP BY 1
  ORDER BY COUNT(msg_id) DESC
  LIMIT 5
'''
con.execute(SQL).fetch_df()
# Out:
#     channel_id  msg_cnt
# 0  C021FSDN7LJ       42
# 1  C01U6P7LZ8F       42
# 2  C01B4PVGLVB       37
# 3  C0227A51SAY       32
# 4  C0220KU9399       18

# %% [markdown]
# ### TODO#7 (Optional): Pandas
# * Thực hiện lại các thao tác trong `TODO#6.2` bằng Python Pandas

# %%
# YOUR CODE
